# %% [markdown]
# # Trovo gli scarti minimi in angoli_validi_step1_from0

# %%
import numpy as np

# %% [markdown]
# ## Lettura dei dati

# %%
# PRIMA parte dei dati
data = np.loadtxt('data_to_180/con_prominence/angoli_validi_step1_from0_to110.txt', skiprows=1)
scarti1 = data[:, 3]
minimo1 = 10000
secondo_minimo1 = 10000
terzo_minimo1 = 10000

# prima devo cercare il minimo
for i, scarto in enumerate(scarti1):
    if scarto < minimo1:
        terzo_minimo1 = secondo_minimo1
        secondo_minimo1 = minimo1
        minimo1 = scarto

# poi devo andare a vedere quante volte in realtà compare quel minimo
indici_minimi_1 = [i for i, scarto in enumerate(scarti1) if scarto == minimo1]
indici_secondi_minimi_1 = [i for i, scarto in enumerate(scarti1) if scarto == secondo_minimo1]
indici_terzi_minimi_1 = [i for i, scarto in enumerate(scarti1) if scarto == terzo_minimo1]

# quindi trattengo solo gli scarti minimi
scarti_minimi_1 = scarti1[indici_minimi_1]
scarti_secondi_minimi_1 = scarti1[indici_secondi_minimi_1]
scarti_terzi_minimi_1 = scarti1[indici_terzi_minimi_1]

# e salvo le terne di angoli corrispondenti
angoli_minimi_1 = np.column_stack([
    data[indici_minimi_1, 0],
    data[indici_minimi_1, 1],
    data[indici_minimi_1, 2],
])

angoli_secondi_minimi_1 = np.column_stack([
    data[indici_secondi_minimi_1, 0],
    data[indici_secondi_minimi_1, 1],
    data[indici_secondi_minimi_1, 2],
])

angoli_terzi_minimi_1 = np.column_stack([
    data[indici_terzi_minimi_1, 0],
    data[indici_terzi_minimi_1, 1],
    data[indici_terzi_minimi_1, 2],
])

# libero la memoria
del data

# SECONDA PARTE DEI DATI - il minimo sta di là!
data = np.loadtxt('data_to_180/con_prominence/angoli_validi_step1_from110_to180.txt', skiprows=1, usecols=range(4))
scarti2 = data[:, 3]
minimo2 = 10000
secondo_minimo2 = 10000
terzo_minimo2 = 10000

# prima devo cercare il minimo
for i, scarto in enumerate(scarti2):
    if scarto < minimo2:
        terzo_minimo2 = secondo_minimo2
        secondo_minimo2 = minimo2
        minimo2 = scarto

# poi devo andare a vedere quante volte in realtà compare quel minimo
indici_minimi_2 = [i for i, scarto in enumerate(scarti2) if scarto == minimo2]
indici_secondi_minimi_2 = [i for i, scarto in enumerate(scarti2) if scarto == secondo_minimo2]
indici_terzi_minimi_2 = [i for i, scarto in enumerate(scarti2) if scarto == terzo_minimo2]

# quindi trattengo solo gli scarti minimi
scarti_minimi_2 = scarti2[indici_minimi_2]
scarti_secondi_minimi_2 = scarti2[indici_secondi_minimi_2]
scarti_terzi_minimi_2 = scarti2[indici_terzi_minimi_2]

# e salvo le terne di angoli corrispondenti
angoli_minimi_2 = np.column_stack([
    data[indici_minimi_2, 0],
    data[indici_minimi_2, 1],
    data[indici_minimi_2, 2],
])

angoli_secondi_minimi_2 = np.column_stack([
    data[indici_secondi_minimi_2, 0],
    data[indici_secondi_minimi_2, 1],
    data[indici_secondi_minimi_2, 2],
])

angoli_terzi_minimi_2 = np.column_stack([
    data[indici_terzi_minimi_2, 0],
    data[indici_terzi_minimi_2, 1],
    data[indici_terzi_minimi_2, 2],
])

# libero la memoria
del data

# %% [markdown]
# ### Controllo da che parte sta il minimo

# %% [markdown]
# #### primo minimo

# %%
if minimo1 < minimo2:
    print("Il minimo sta tra 0 e 110")
elif minimo1 == minimo2:
    print("C'è un minimo in entrambe le regioni")
elif minimo1 > minimo2:
    print("Il minimo sta tra 110 e 180")
# Out:
# C'è un minimo in entrambe le regioni

# %% [markdown]
# #### secondo minimo

# %%
if secondo_minimo1 < secondo_minimo2:
    print(f"Il secondo minimo sta tra 0 e 110 ed è {secondo_minimo1}")
elif secondo_minimo1 == secondo_minimo2:
    print(f"C'è un secondo minimo in entrambe le regioni ed è {secondo_minimo1}")
elif secondo_minimo1 > secondo_minimo2:
    print(f"Il secondo minimo sta tra 110 e 180 ed è {secondo_minimo2}")
# Out:
# Il secondo minimo sta tra 110 e 180 ed è 0.037677629

# %% [markdown]
# #### terzo minimo

# %%
if terzo_minimo1 < terzo_minimo2:
    print(f"Il terzo minimo sta tra 0 e 110 ed è {terzo_minimo1}")
elif terzo_minimo1 == terzo_minimo2:
    print(f"C'è un terzo minimo in entrambe le regioni ed è {terzo_minimo1}")
elif terzo_minimo1 > terzo_minimo2:
    print(f"Il terzo minimo sta tra 110 e 180 ed è {terzo_minimo2}")
# Out:
# Il terzo minimo sta tra 110 e 180 ed è 0.038028358

# %%
# vediamo quanti sono i minimi
print('primi', len(indici_minimi_1), len(indici_minimi_2))
print('secondi', len(indici_secondi_minimi_1), len(indici_secondi_minimi_2))
print('terzi', len(indici_terzi_minimi_1), len(indici_terzi_minimi_2))
# Out:
# primi 620 300
# secondi 4 2
# terzi 1 2

# %%
print(angoli_terzi_minimi_1)
# Out:
# [[ 0. 27. 20.]]

# %%
print(angoli_terzi_minimi_2)
# Out:
# [[110.  25.  62.]
#  [110.  25. 152.]]

# %%
angoli_minimi_2
# Out:
# array([[110.,  66.,  11.],
#        [110.,  66.,  79.],
#        [110.,  66., 101.],
#        [110.,  66., 169.],
#        [110., 114.,  11.],
#        [110., 114.,  79.],
#        [110., 114., 101.],
#        [110., 114., 169.],
#        [111.,  66.,  11.],
#        [111.,  66.,  79.],
#        [111.,  66., 101.],
#        [111.,  66., 169.],
#        [111., 114.,  11.],
#        [111., 114.,  79.],
#        [111., 114., 101.],
#        [111., 114., 169.],
#        [112.,  66.,  11.],
#        [112.,  66.,  79.],
#        [112.,  66., 101.],
#        [112.,  66., 169.],
#        [112., 114.,  11.],
#        [112., 114.,  79.],
#        [112., 114., 101.],
#        [112., 114., 169.],
#        [113.,  66.,  11.],
#        [113.,  66.,  79.],
#        [113.,  66., 101.],
#        [113.,  66., 169.],
#        [113., 114.,  11.],
#        [113., 114.,  79.],
#        [113., 114., 101.],
#        [113., 114., 169.],
#        [114.,  66.,  11.],
#        [114.,  66.,  79.],
#        [114.,  66., 101.],
#        [114.,  66., 169.],
#        [114., 114.,  11.],
#        [114., 114.,  79.],
#        [114., 114., 101.],
#        [114., 114., 169.],
#        [115.,  66.,  11.],
#        [115.,  66.,  79.],
#        [115.,  66., 101.],
#        [115.,  66., 169.],
#        [115., 114.,  11.],
#        [115., 114.,  79.],
#        [115., 114., 101.],
#        [115., 114., 169.],
#        [116.,  66.,  11.],
#        [116.,  66.,  79.],
#        [116.,  66., 101.],
#        [116.,  66., 169.],
#        [116., 114.,  11.],
#        [116., 114.,  79.],
#        [116., 114., 101.],
#        [116., 114., 169.],
#        [117.,  66.,  11.],
#        [117.,  66.,  79.],
#        [117.,  66., 101.],
#        [117.,  66., 169.],
#        [166.,  66.,  11.],
#        [166.,  66.,  79.],
#        [166.,  66., 101.],
#        [166.,  66., 169.],
#        [166., 114.,  11.],
#        [166., 114.,  79.],
#        [166., 114., 101.],
#        [166., 114., 169.],
#        [167.,  66.,  11.],
#        [167.,  66.,  79.],
#        [167.,  66., 101.],
#        [167.,  66., 169.],
#        [167., 114.,  11.],
#        [167., 114.,  79.],
#        [167., 114., 101.],
#        [167., 114., 169.],
#        [168.,  66.,  11.],
#        [168.,  66.,  79.],
#        [168.,  66., 101.],
#        [168.,  66., 169.],
#        [168., 114.,  11.],
#        [168., 114.,  79.],
#        [168., 114., 101.],
#        [168., 114., 169.],
#        [169.,  66.,  11.],
#        [169.,  66.,  79.],
#        [169.,  66., 101.],
#        [169.,  66., 169.],
#        [169., 114.,  11.],
#        [169., 114.,  79.],
#        [169., 114., 101.],
#        [169., 114., 169.],
#        [170.,  66.,  11.],
#        [170.,  66.,  79.],
#        [170.,  66., 101.],
#        [170.,  66., 169.],
#        [170., 114.,  11.],
#        [170., 114.,  79.],
#        [170., 114., 101.],
#        [170., 114., 169.],
#        [171.,  66.,  11.],
#        [171.,  66.,  79.],
#        [171.,  66., 101.],
#        [171.,  66., 169.],
#        [171., 114.,  11.],
#        [171., 114.,  79.],
#        [171., 114., 101.],
#        [171., 114., 169.],
#        [172.,  66.,  11.],
#        [172.,  66.,  79.],
#        [172.,  66., 101.],
#        [172.,  66., 169.],
#        [172., 114.,  11.],
#        [172., 114.,  79.],
#        [172., 114., 101.],
#        [172., 114., 169.],
#        [173.,  66.,  11.],
#        [173.,  66.,  79.],
#        [173.,  66., 101.],
#        [173.,  66., 169.],
#        [173., 114.,  11.],
#        [173., 114.,  79.],
#        [173., 114., 101.],
#        [173., 114., 169.],
#        [174.,  66.,  11.],
#        [174.,  66.,  79.],
#        [174.,  66., 101.],
#        [174.,  66., 169.],
#        [174., 114.,  11.],
#        [174., 114.,  79.],
#        [174., 114., 101.],
#        [174., 114., 169.],
#        [175.,  66.,  11.],
#        [175.,  66.,  79.],
#        [175.,  66., 101.],
#        [175.,  66., 169.],
#        [175., 114.,  11.],
#        [175., 114.,  79.],
#        [175., 114., 101.],
#        [175., 114., 169.],
#        [176.,  66.,  11.],
#        [176.,  66.,  79.],
#        [176.,  66., 101.],
#        [176.,  66., 169.],
#        [176., 114.,  11.],
#        [176., 114.,  79.],
#        [176., 114., 101.],
#        [176., 114., 169.],
#        [177.,  66.,  11.],
#        [177.,  66.,  79.],
#        [177.,  66., 101.],
#        [177.,  66., 169.],
#        [177., 114.,  11.],
#        [177., 114.,  79.],
#        [177., 114., 101.],
#        [177., 114., 169.],
#        [178.,  66.,  11.],
#        [178.,  66.,  79.],
#        [178.,  66., 101.],
#        [178.,  66., 169.],
#        [178., 114.,  11.],
#        [178., 114.,  79.],
#        [178., 114., 101.],
#        [178., 114., 169.],
#        [179.,  66.,  11.],
#        [179.,  66.,  79.],
#        [179.,  66., 101.],
#        [179.,  66., 169.],
#        [179., 114.,  11.],
#        [179., 114.,  79.],
#        [179., 114., 101.],
#        [179., 114., 169.],
#        [180.,  66.,  11.],
#        [180.,  66.,  79.],
#        [180.,  66., 101.],
#        [180.,  66., 169.],
#        [180., 114.,  11.],
#        [180., 114.,  79.],
#        [180., 114., 101.],
#        [180., 114., 169.]])
