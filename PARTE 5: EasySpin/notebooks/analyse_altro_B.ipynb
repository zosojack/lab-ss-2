# %% [markdown]
# # 4 centrali + 2 carbonio13

# %%
import numpy as np
filename = '../data_to_180/con_prominence/angoli_validi_step5_from0_to180_B1_5.txt'
data = np.loadtxt(filename, skiprows=1)

# %%
minimo_assoluto = np.min(np.abs(data[:,3]))
lista_angoli_minimi = [(data[i, 0], data[i, 1], data[i, 2]) for i in range(len(data)) if np.abs(data[i, 3]) == minimo_assoluto]

# %%
minimo_assoluto
# Out:
# np.float64(0.00057308159)

# %%
lista_angoli_minimi
# Out:
# [(np.float64(75.0), np.float64(50.0), np.float64(60.0)),
#  (np.float64(75.0), np.float64(50.0), np.float64(150.0)),
#  (np.float64(75.0), np.float64(130.0), np.float64(30.0)),
#  (np.float64(75.0), np.float64(130.0), np.float64(120.0)),
#  (np.float64(80.0), np.float64(50.0), np.float64(60.0)),
#  (np.float64(80.0), np.float64(50.0), np.float64(150.0)),
#  (np.float64(80.0), np.float64(130.0), np.float64(30.0)),
#  (np.float64(80.0), np.float64(130.0), np.float64(120.0)),
#  (np.float64(100.0), np.float64(50.0), np.float64(30.0)),
#  (np.float64(100.0), np.float64(50.0), np.float64(120.0)),
#  (np.float64(100.0), np.float64(130.0), np.float64(60.0)),
#  (np.float64(100.0), np.float64(130.0), np.float64(150.0)),
#  (np.float64(105.0), np.float64(50.0), np.float64(30.0)),
#  (np.float64(105.0), np.float64(50.0), np.float64(120.0)),
#  (np.float64(105.0), np.float64(130.0), np.float64(60.0)),
#  (np.float64(105.0), np.float64(130.0), np.float64(150.0))]

# %% [markdown]
# | alpha | beta | gamma |
# | ---: | ---: | ---: |
# | 153 | 23  | 26  |
# | 153 | 23  | 116 |
# | 153 | 157 | 64  |
# | 153 | 157 | 154 |
